# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement (1).csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
def quanqual(dataset):
    quan=[]  
    qual=[]  
    for columnName in dataset.columns:
    #print(columnName)
        if(dataset[columnName].dtype=='O'):
        #print("qual")
            qual.append(columnName)
        else:
        #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanqual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan,qual=quanqual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
# 1) Replace the NaN values with correct value. and justify why you have chosen the same.

# %%
median_salary = dataset['salary'].median()

# Replace NaN values in 'salary' with the median
dataset['salary'].fillna(median_salary, inplace=True)

# Check if there are any other NaN values in the dataset
nan_check = dataset.isnull().sum()

# Print the result
print("NaN values after replacement:\n", nan_check)
# Out:
# NaN values after replacement:
#  sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          215 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
# 2. how many of them are not placed?

# %%
not_placed=dataset['status'].value_counts().get('Not Placed', 0)
print("Number of students not placed:\n",not_placed)
# Out:
# Number of students not placed:
#  67

# %%
not_placed=dataset['status'].value_counts()
print("Number of students placed and not placed:\n",not_placed)
# Out:
# Number of students placed and not placed:
#  Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %%
# 3. find the reason for non placement from the dataset

# %%
not_placed_data = dataset[dataset['status'] == 'Not Placed']

student_performance = ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'mba_p']

reason_analysis = not_placed_data[student_performance]

# Summary statistics(academic performance)
reason_stats = reason_analysis.describe()
print(reason_stats)
# Out:
#            ssc_p      hsc_p   degree_p    etest_p      mba_p
# count  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   57.544030  58.395522  61.134179  69.587910  61.612836
# std     8.394246   9.914090   6.365825  11.930687   5.705689
# min    40.890000  37.000000  50.000000  50.000000  51.210000
# 25%    52.000000  51.000000  57.000000  60.000000  58.480000
# 50%    56.280000  60.330000  61.000000  67.000000  60.690000
# 75%    63.000000  64.000000  65.000000  76.500000  65.405000
# max    77.800000  82.000000  79.000000  97.000000  75.710000

# %%
correlation_matrix = reason_analysis.corr()
print(correlation_matrix)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p
# ssc_p     1.000000  0.340030  0.291363  0.012215  0.434229
# hsc_p     0.340030  1.000000  0.342820  0.036848  0.441932
# degree_p  0.291363  0.342820  1.000000  0.109484  0.238300
# etest_p   0.012215  0.036848  0.109484  1.000000  0.017030
# mba_p     0.434229  0.441932  0.238300  0.017030  1.000000

# %%
covariance_matrix = reason_analysis.cov()
print(covariance_matrix)
# Out:
#               ssc_p      hsc_p   degree_p     etest_p      mba_p
# ssc_p     70.463364  28.297747  15.569348    1.223363  20.797391
# hsc_p     28.297747  98.289180  21.635861    4.358412  24.998649
# degree_p  15.569348  21.635861  40.523734    8.315144   8.655396
# etest_p    1.223363   4.358412   8.315144  142.341280   1.159298
# mba_p     20.797391  24.998649   8.655396    1.159298  32.554884

# %%
import matplotlib.pyplot as plt
# Out:
# Bad key text.latex.preview in file C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# ...

# %%
import seaborn as sns
sns.pairplot(reason_analysis)

# %%
# 4) what kind of relation between salary and mba_p?

# %%
correlation=dataset['salary'].corr(dataset['mba_p'])

# %%
print("correlation between salary and MBA percentage:\n",correlation)
# Out:
# correlation between salary and MBA percentage:
#  0.15567343961944688

# %%
# 5) which specialization is getting minimum salary?

# %%
#groupby is a function used to group rows of a DataFrame based on specified criteria, typically a column's values
specialization_min_salary = dataset.groupby('specialisation')['salary'].min()

# Identify the specialization with the minimum salary
min_salary_specialization = specialization_min_salary.idxmin()
min_salary_value = specialization_min_salary.min()

print(f"Specialization with Minimum Salary: {min_salary_specialization}")
print(f"Minimum Salary: {min_salary_value}")
# Out:
# Specialization with Minimum Salary: Mkt&Fin
# Minimum Salary: 200000.0

# %%
# 6) How many of them getting above 500000 salary?

# %%
above_500k = dataset[dataset['salary'] >500000]
above_500k
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
above_500k = dataset[dataset['salary'] >=500000]
above_500k
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 77      78      M  64.00   Others  80.00   Others   Science     65.00
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 150    151      M  71.00  Central  58.66  Central   Science     58.00
# 163    164      M  63.00   Others  67.00   Others   Science     64.00
# 174    175      M  73.24   Others  50.83   Others   Science     64.27
# 177    178      F  73.00  Central  97.00   Others  Commerce     79.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 77    Sci&Tech    Yes    69.00        Mkt&Fin  57.65  Placed  500000.0
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 163   Sci&Tech     No    75.00        Mkt&Fin  66.46  Placed  500000.0
# 174   Sci&Tech    Yes    64.00        Mkt&Fin  66.23  Placed  500000.0
# ...

# %%
# 7) Test the analysis of variance between etest_p and mba_p at significance level 5%.
# (make decision using hypothesis testing)

# %%
from scipy.stats import stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
from scipy.stats import f_oneway
import seaborn as sns
import matplotlib.pyplot as plt


etest_p = dataset['etest_p']
mba_p = dataset['mba_p']

# Perform ANOVA test
statistic, p_value = f_oneway(etest_p, mba_p)

# Set significance level
alpha = 0.05

# Make decision
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in means.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in means.")
# Out:
# Reject the null hypothesis. There is a significant difference in means.

# %%
# 8) Test the similarity between the degree_t(sci&Tech) and specialisation(Mkt&HR)with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind



# Select data for Science & Technology degree
science_tech_salary = dataset[dataset['degree_t'] == 'Sci&Tech']['salary'].dropna()

# Select data for Mkt&HR specialization
mkt_hr_salary = dataset[dataset['specialisation'] == 'Mkt&HR']['salary'].dropna()

# Perform independent two-sample t-test
statistic, p_value = ttest_ind(science_tech_salary, mkt_hr_salary)

# Set significance level
alpha = 0.05

# Make decision
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in means.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in means.")
# Out:
# Reject the null hypothesis. There is a significant difference in means.

# %%
#9) convert the normal distribution to standard normal distribution for salary column

# %%
from scipy.stats import zscore

# Replace 'salary_column_name' with the actual column name in your dataset
salary_column_name = 'salary'

# Calculate Z-scores for the 'salary' column
dataset['salary_zscore'] = zscore(dataset[salary_column_name])

# Now, the 'salary_zscore' column contains the Z-scores

# %%
dataset['salary_zscore']
# Out:
# 0     -0.144570
# 1     -1.041427
# 2     -0.400815
# 3     -0.208631
# 4      1.841328
#          ...
# 210    1.521022
# 211   -0.080509
# 212    0.175736
# 213   -0.990178
# 214   -0.208631
# Name: salary_zscore, Length: 215, dtype: float64

# %%
# Plot histogram for the original 'salary' column
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(dataset[salary_column_name], kde=True)
plt.title('Original Salary Distribution')

# Plot histogram for the Z-scores
plt.subplot(1, 2, 2)
sns.histplot(dataset['salary_zscore'], kde=True)
plt.title('Standard Normal Distribution (Z-scores)')

plt.show()

# %%
#10) what is the probability density function of the salary range from 700000 to  900000?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Replace 'salary_column_name' with the actual column name in your dataset
salary_column_name = 'salary'

# Filter dataset for the specified salary range
salary_range = dataset[(dataset[salary_column_name] >= 700000) & (dataset[salary_column_name] <= 900000)]

# Plot the KDE plot for the salary range
plt.figure(figsize=(8, 6))
sns.kdeplot(salary_range[salary_column_name], fill=True, bw_method=None)
plt.title('Probability Density Function for Salary Range 700,000 to 900,000')
plt.xlabel('Salary')
plt.ylabel('Probability Density')
plt.show()

# %%
#Noone is getting salary between 700000 to 900000.
salary_range = dataset[(dataset[salary_column_name] >= 500000) & (dataset[salary_column_name] <= 700000)]
salary_range
#5 student is getting salary between 500000 to 700000.
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 77      78      M  64.00   Others  80.00   Others   Science     65.00
# 150    151      M  71.00  Central  58.66  Central   Science     58.00
# 163    164      M  63.00   Others  67.00   Others   Science     64.00
# 174    175      M  73.24   Others  50.83   Others   Science     64.27
# 177    178      F  73.00  Central  97.00   Others  Commerce     79.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary  \
# 77    Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 150   Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 163   Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 174   Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 177  Comm&Mgmt    Yes     89.0        Mkt&Fin  70.81  Placed  650000.0
#
#      salary_zscore
# 77        2.802246
# 150       5.236571
# 163       2.802246
# 174       2.802246
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Replace 'salary_column_name' with the actual column name in your dataset
salary_column_name = 'salary'

# Filter dataset for the specified salary range
salary_range = dataset[(dataset[salary_column_name] >= 500000) & (dataset[salary_column_name] <= 700000)]

# Plot the KDE plot for the salary range
plt.figure(figsize=(8, 6))
sns.kdeplot(salary_range[salary_column_name], fill=True, bw_method=None)
plt.title('Probability Density Function for Salary Range 700,000 to 900,000')
plt.xlabel('Salary')
plt.ylabel('Probability Density')
plt.show()

# %%
#11) Test the similarity between the degree_t(sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats


data_sci_tech = dataset[dataset['degree_t'] == 'Sci&Tech']

# Calculate the differences
differences = data_sci_tech['etest_p'] - data_sci_tech['mba_p']

# Perform paired sample t-test
t_stat, p_value = stats.ttest_rel(data_sci_tech['etest_p'], data_sci_tech['mba_p'])

# Compare p-value to significance level
alpha = 0.05
if p_value <= alpha:
    print("Reject the null hypothesis. There is a significant difference.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference.")
# Out:
# Reject the null hypothesis. There is a significant difference.

# %%
# 12) Which Parameter is highly correlated with salary?

# %%
import pandas as pd


correlation_matrix = dataset.corr()

# Extract correlation with 'salary'
salary_correlation = correlation_matrix['salary']

# Sort correlations in descending order
sorted_correlations = salary_correlation.abs().sort_values(ascending=False)


print(sorted_correlations)
# Out:
# salary_zscore    1.000000
# salary           1.000000
# etest_p          0.169233
# mba_p            0.155673
# hsc_p            0.122921
# ssc_p            0.108669
# degree_p         0.053352
# sl_no            0.047270
# Name: salary, dtype: float64

# %%
# 13)plot any useful graph and explain it

# %%
import seaborn as sb
import matplotlib.pyplot as plt

sb.jointplot(x='etest_p', y='mba_p', data=dataset, kind='hex')
plt.show()
